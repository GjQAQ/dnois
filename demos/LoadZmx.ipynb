# %%
from dnois.ext.zmx import zmx2sq
from dnois.optics import rt
import torch

# %%
torch.set_grad_enabled(False)

# %%
slist = zmx2sq('Kohler illumination.zmx')
optics = rt.CoaxialRayTracing(slist, depth=0.1)

# %%
optics.plot_cross_section(height=[-12.7e-3, 0., 12.7e-3], legend=False)
# Out:
# (<Figure size 1280x960 with 1 Axes>, <Axes: xlabel='$z/m$', ylabel='$y/m$'>)
